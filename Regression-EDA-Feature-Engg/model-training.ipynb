# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv', delim_whitespace=True)
# Out:
# C:\Users\Adit Sharma\AppData\Local\Temp\ipykernel_18584\2638225438.py:1: FutureWarning: The 'delim_whitespace' keyword in pd.read_csv is deprecated and will be removed in a future version. Use ``sep='\s+'`` instead
#   df = pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv', delim_whitespace=True)

# %%
df.head()
# Out:
#                                                    Bejaia   Region  \
# day,month,year,Temperature,                           RH,  Ws,Rain
# 01,06,2012,29,57,18,0,65.7,3.4,7.6,1.3,3.4,0.5,not   fire      NaN
# 02,06,2012,29,61,13,1.3,64.4,4.1,7.6,1,3.9,0.4,not   fire      NaN
# 03,06,2012,26,82,22,13.1,47.1,2.5,7.1,0.3,2.7,0...   fire      NaN
# 04,06,2012,25,89,13,2.5,28.6,1.3,6.9,0,1.7,0,not     fire      NaN
#
#                                                                              Dataset
# day,month,year,Temperature,                         ,FFMC,DMC,DC,ISI,BUI,FWI,Classes
# 01,06,2012,29,57,18,0,65.7,3.4,7.6,1.3,3.4,0.5,not                               NaN
# 02,06,2012,29,61,13,1.3,64.4,4.1,7.6,1,3.9,0.4,not                               NaN
# 03,06,2012,26,82,22,13.1,47.1,2.5,7.1,0.3,2.7,0...                               NaN
# 04,06,2012,25,89,13,2.5,28.6,1.3,6.9,0,1.7,0,not                                 NaN

# %%
df.columns
# Out:
# Index(['Bejaia', 'Region', 'Dataset'], dtype='object')

# %%
df.drop(['day','month','year'], axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df.drop(['day','month','year'], axis=1, inplace=True)
#
# File c:\Users\Adit Sharma\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
# ...
